# %%
# !pip install nibabel scikit-learn scipy torchvision torchio
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (5.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Collecting torchio
#   Downloading torchio-0.20.8-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel) (4.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.6.0+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->torchvision)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Collecting deprecated>=1.2 (from torchio)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.11/dist-packages (from torchio) (0.8.1)
# Requirement already satisfied: humanize>=0.1 in /usr/local/lib/python3.11/dist-packages (from torchio) (4.12.3)
# Requirement already satisfied: rich>=10 in /usr/local/lib/python3.11/dist-packages (from torchio) (13.9.4)
# Collecting simpleitk!=2.0.*,!=2.1.1.1,>=1.3 (from torchio)
#   Downloading simpleitk-2.5.0-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: tqdm>=4.40 in /usr/local/lib/python3.11/dist-packages (from torchio) (4.67.1)
# Requirement already satisfied: typer>=0.1 in /usr/local/lib/python3.11/dist-packages (from torchio) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2->torchio) (1.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10->torchio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10->torchio) (2.19.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.1->torchio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.1->torchio) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10->torchio) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.3 MB/s eta 0:00:00
# Downloading torchio-0.20.8-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 15.6 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading simpleitk-2.5.0-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 49.5 MB/s eta 0:00:00
# Installing collected packages: simpleitk, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, deprecated, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchio
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed deprecated-1.2.18 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 simpleitk-2.5.0 torchio-0.20.8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import nibabel as nib
from scipy.ndimage import zoom
import torch
from torch.utils.data import Dataset
import torchio as tio

class MRIDataset(Dataset):
    def __init__(self, root_dir, target_shape=(32, 112, 112), ad_repeat=2, augment=True):
        self.file_paths = []
        self.labels = []
        self.target_shape = target_shape
        self.augment = augment

        # Augmentasyon - tüm sınıflara uygulanır
        self.transform = tio.Compose([
            tio.RandomFlip(axes=('LR', 'AP', 'IS'), p=0.5),
            #sol-sağ,ön-arka,alt-üst dönüşüm her birine %50 olasaılık
            tio.RandomAffine(scales=(0.9, 1.1), degrees=10, translation=5, p=0.7),
            #scales=(0.9, 1.1): Görüntüyü %90–110 arasında ölçekler.
            #degrees=10: Her eksende en fazla ±10 derece döndürme.
            #translation=5: Maksimum 5 voxel kaydırma (x, y, z yönünde).
            #p=0.7: Uygulanma olasılığı %70.
            tio.RandomNoise(mean=0.0, std=0.1, p=0.4),
            #Rastgele Gauss gürültüsü ekleyerek modeli gürültüye karşı daha dayanıklı hale getirir.
            tio.RandomBiasField(p=0.3),
            #MRI verilerinde sıkça görülen manyetik alan bozulmalarını taklit eden "bias field" etkisi ekler.
        ])

        class_folders = ['CN_Combined', 'MCI_Combined', 'AD_Combined']
        for label, class_name in enumerate(class_folders):
            class_path = os.path.join(root_dir, class_name)
            if not os.path.exists(class_path): continue

            for subject_folder in os.listdir(class_path):
                full_subject_path = os.path.join(class_path, subject_folder)
                if not os.path.isdir(full_subject_path): continue
                orig_path = os.path.join(full_subject_path, "mri", "orig.mgz")
                if os.path.isfile(orig_path):
                    # AD örneklerini çoğalt (dosya yolu düzeyinde)
                    repeat = ad_repeat if class_name == 'AD_Combined' else 1
                    for _ in range(repeat):
                        self.file_paths.append(orig_path)
                        self.labels.append(label)

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        path = self.file_paths[idx]
        label = self.labels[idx]

        img = nib.load(path).get_fdata()
        img = (img - np.mean(img)) / np.std(img)

        # Hedef shape'e yeniden boyutlandır
        zoom_factors = [t / s for t, s in zip(self.target_shape, img.shape)]
        img = zoom(img, zoom_factors, order=1)
        img = np.expand_dims(img, axis=0)  # [1, D, H, W]

        # Eğer augmentasyon uygulanacaksa
        if self.augment:
            subject = tio.Subject(mri=tio.ScalarImage(tensor=torch.tensor(img)))
            transformed = self.transform(subject)
            img = transformed.mri.data

        return torch.tensor(img, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
from torch.utils.data import Dataset
from torch.utils.data import random_split, DataLoader

# Veri yolu
data_dir = '/content/drive/MyDrive/Processed'

# Dataset'i yükle (AD çoğaltması dahil)
dataset = MRIDataset(data_dir, ad_repeat=2)

# Dataset kontrolü
print(f"Toplam örnek sayısı: {len(dataset)}")

if len(dataset) > 0:
    print("✅ Dosyalar bulundu. İlk 5 dosya yolu:")
    for i in range(min(5, len(dataset))):
        print(dataset.file_paths[i])
else:
    raise ValueError("❌ Hiç dosya bulunamadı. Lütfen klasör yapısını ve yolunu kontrol et.")

# Dataset bölme (80% train, 10% val, 10% test)
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size  # kalan

train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])

# Validation ve Test için augmentasyonu kapatalım
val_ds.dataset.augment = False
test_ds.dataset.augment = False

# DataLoader'lar
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=32)
test_loader = DataLoader(test_ds, batch_size=32)

print(f"\n🔍 Dataset Bölümü:")
print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")
# Out:
# Toplam örnek sayısı: 2635
# ✅ Dosyalar bulundu. İlk 5 dosya yolu:
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0602_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20061212103139908_S15966_I32672_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0602_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070921133414775_S37063_I74184_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0602_MR_MPR-R__GradWarp__B1_Correction__N3__Scaled_Br_20081022100531771_S53480_I122635_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0610_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20061212102204007_S15727_I32667_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0610_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20100105121702239_S72045_I162057_CN/mri/orig.mgz
#
# 🔍 Dataset Bölümü:
# Train: 2108 | Val: 263 | Test: 264

# %%
from torch.utils.data import random_split, DataLoader

# Veri yolu
data_dir = '/content/drive/MyDrive/Processed'

# Dataset'i yükle (AD çoğaltması dahil)
dataset = MRIDataset(data_dir, ad_repeat=2)

# Dataset kontrolü
print(f"Toplam örnek sayısı: {len(dataset)}")

if len(dataset) > 0:
    print("✅ Dosyalar bulundu. İlk 5 dosya yolu:")
    for i in range(min(5, len(dataset))):
        print(dataset.file_paths[i])
else:
    raise ValueError("❌ Hiç dosya bulunamadı. Lütfen klasör yapısını ve yolunu kontrol et.")

# Dataset bölme (80% train, 10% val, 10% test)
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size  # kalan

train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])

# Validation ve Test için augmentasyonu kapatalım
val_ds.dataset.augment = False
test_ds.dataset.augment = False

# DataLoader'lar
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=32)
test_loader = DataLoader(test_ds, batch_size=32)

print(f"\n🔍 Dataset Bölümü:")
print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")
# Out:
# Toplam örnek sayısı: 2635
# ✅ Dosyalar bulundu. İlk 5 dosya yolu:
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0602_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20061212103139908_S15966_I32672_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0602_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070921133414775_S37063_I74184_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0602_MR_MPR-R__GradWarp__B1_Correction__N3__Scaled_Br_20081022100531771_S53480_I122635_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0610_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20061212102204007_S15727_I32667_CN/mri/orig.mgz
# /content/drive/MyDrive/Processed/CN_Combined/ADNI_005_S_0610_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20100105121702239_S72045_I162057_CN/mri/orig.mgz
#
# 🔍 Dataset Bölümü:
# Train: 2108 | Val: 263 | Test: 264

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

# 3D DenseLayer: DenseNet'in yapı taşı
class _DenseLayer3D(nn.Module):
    def __init__(self, in_channels, growth_rate, bn_size=4, drop_rate=0):
        super().__init__()
        self.norm1 = nn.BatchNorm3d(in_channels)
        self.relu1 = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv3d(in_channels, bn_size * growth_rate, kernel_size=1, stride=1, bias=False)

        self.norm2 = nn.BatchNorm3d(bn_size * growth_rate)
        self.relu2 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv3d(bn_size * growth_rate, growth_rate, kernel_size=3, stride=1, padding=1, bias=False)

        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = self.conv1(self.relu1(self.norm1(x)))
        new_features = self.conv2(self.relu2(self.norm2(new_features)))
        if self.drop_rate > 0:
            new_features = F.dropout3d(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)


# 3D DenseBlock
class _DenseBlock3D(nn.Module):
    def __init__(self, num_layers, in_channels, growth_rate, bn_size=4, drop_rate=0):
        super().__init__()
        layers = []
        for i in range(num_layers):
            layers.append(_DenseLayer3D(in_channels + i * growth_rate, growth_rate, bn_size, drop_rate))
        self.block = nn.Sequential(*layers)

    def forward(self, x):
        return self.block(x)


# 3D Transition layer
class _Transition3D(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.norm = nn.BatchNorm3d(in_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv = nn.Conv3d(in_channels, out_channels, kernel_size=1, stride=1, bias=False)
        self.pool = nn.AvgPool3d(kernel_size=2, stride=2)

    def forward(self, x):
        x = self.conv(self.relu(self.norm(x)))
        x = self.pool(x)
        return x


# 3D DenseNet modeli
class DenseNet3D(nn.Module):
    def __init__(self, num_classes=3, growth_rate=32, block_config=(6, 12, 24, 16),
                 num_init_features=64, bn_size=4, drop_rate=0):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv3d(1, num_init_features, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm3d(num_init_features),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=3, stride=2, padding=1)
        )

        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock3D(num_layers, num_features, growth_rate, bn_size, drop_rate)
            self.features.add_module(f'denseblock{i+1}', block)
            num_features += num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition3D(num_features, num_features // 2)
                self.features.add_module(f'transition{i+1}', trans)
                num_features = num_features // 2

        self.features.add_module('norm_final', nn.BatchNorm3d(num_features))

        self.classifier = nn.Sequential(
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool3d((1, 1, 1)),
            nn.Flatten(),
            nn.Linear(num_features, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(256, num_classes)
        )

        self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv3d):
                init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm3d):
                init.constant_(m.weight, 1)
                init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                init.constant_(m.bias, 0)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DenseNet3D(num_classes=3).to(device)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

def evaluate_model(loader, name):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            correct += (preds == labels).sum().item()
            total += labels.size(0)
            total_loss += loss.item()

    avg_loss = total_loss / len(loader)
    acc = correct / total * 100
    print(f"{name} | Accuracy: {acc:.2f}% | Loss: {avg_loss:.4f}")

    # Ek metrikler
    print("\n📊 Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=["CN", "MCI", "AD"], digits=4))

    print("🧩 Confusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))

    return avg_loss, acc

# Eğitim parametreleri
num_epochs = 12
patience = 3
best_val_loss = float('inf')
epochs_without_improvement = 0

print(f"\nTrain: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    print(f"\nEpoch {epoch+1}/{num_epochs}")

    for batch_idx, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

        if (batch_idx + 1) % 2 == 0 or (batch_idx + 1) == len(train_loader):
            acc = correct / total * 100
            print(f"  Batch {batch_idx+1} | Loss: {loss.item():.4f} | Accuracy: {acc:.2f}%")

    avg_train_loss = total_loss / len(train_loader)
    train_acc = correct / total * 100
    print(f"Epoch {epoch+1} Sonu | Train Loss: {avg_train_loss:.4f} | Train Accuracy: {train_acc:.2f}%")

    # Doğrulama
    val_loss, val_acc = evaluate_model(val_loader, f"Validation (Epoch {epoch+1})")

    # Erken durdurma kontrolü
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1
        print(f"  ⚠️ Validation loss iyileşmedi. ({epochs_without_improvement}/{patience})")
        if epochs_without_improvement >= patience:
            print(f"  🛑 Validation loss {patience} epoch boyunca iyileşmedi. Eğitim durduruluyor.")
            break

# Final test
print("\n=== Final Test Evaluation ===")
test_loss, test_acc = evaluate_model(test_loader, "Test Set")
# Out:
# Train: 2108 | Val: 263 | Test: 264
#
# Epoch 1/12
#   Batch 2 | Loss: 1.0990 | Accuracy: 18.75%
#   Batch 4 | Loss: 1.0200 | Accuracy: 31.25%
#   Batch 6 | Loss: 1.0306 | Accuracy: 34.90%
#   Batch 8 | Loss: 1.1188 | Accuracy: 35.94%
#   Batch 10 | Loss: 1.1308 | Accuracy: 36.25%
#   Batch 12 | Loss: 1.0789 | Accuracy: 36.72%
#   Batch 14 | Loss: 1.1307 | Accuracy: 36.61%
#   Batch 16 | Loss: 1.1194 | Accuracy: 37.11%
#   Batch 18 | Loss: 1.0913 | Accuracy: 37.50%
#   Batch 20 | Loss: 1.1500 | Accuracy: 37.19%
#   Batch 22 | Loss: 1.0278 | Accuracy: 38.49%
#   Batch 24 | Loss: 0.9733 | Accuracy: 39.58%
#   Batch 26 | Loss: 1.0764 | Accuracy: 39.90%
#   Batch 28 | Loss: 0.9824 | Accuracy: 40.85%
#   Batch 30 | Loss: 0.9769 | Accuracy: 41.35%
#   Batch 32 | Loss: 0.9727 | Accuracy: 42.38%
#   Batch 34 | Loss: 0.9751 | Accuracy: 42.92%
#   Batch 36 | Loss: 1.0982 | Accuracy: 43.23%
#   Batch 38 | Loss: 0.9570 | Accuracy: 43.42%
#   Batch 40 | Loss: 0.9902 | Accuracy: 43.44%
#   Batch 42 | Loss: 1.0484 | Accuracy: 43.68%
#   Batch 44 | Loss: 1.0683 | Accuracy: 43.61%
#   Batch 46 | Loss: 0.9847 | Accuracy: 43.89%
#   Batch 48 | Loss: 0.9394 | Accuracy: 44.60%
#   Batch 50 | Loss: 0.9318 | Accuracy: 45.31%
#   Batch 52 | Loss: 1.1334 | Accuracy: 45.19%
#   Batch 54 | Loss: 0.9912 | Accuracy: 45.83%
#   Batch 56 | Loss: 0.9263 | Accuracy: 46.21%
#   Batch 58 | Loss: 0.9835 | Accuracy: 46.77%
#   Batch 60 | Loss: 0.9442 | Accuracy: 46.88%
#   Batch 62 | Loss: 0.9584 | Accuracy: 47.03%
#   Batch 64 | Loss: 0.9417 | Accuracy: 47.27%
#   Batch 66 | Loss: 0.8923 | Accuracy: 47.34%
# Epoch 1 Sonu | Train Loss: 1.0275 | Train Accuracy: 47.34%
# Validation (Epoch 1) | Accuracy: 46.39% | Loss: 1.0286
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.4312    0.6714    0.5251        70
#          MCI     0.4435    0.5729    0.5000        96
#           AD     0.6667    0.2062    0.3150        97
#
#     accuracy                         0.4639       263
#    macro avg     0.5138    0.4835    0.4467       263
# weighted avg     0.5226    0.4639    0.4384       263
#
# 🧩 Confusion Matrix:
# [[47 23  0]
#  [31 55 10]
#  [31 46 20]]
#
# Epoch 2/12
#   Batch 2 | Loss: 0.9175 | Accuracy: 54.69%
#   Batch 4 | Loss: 0.9613 | Accuracy: 52.34%
#   Batch 6 | Loss: 0.8665 | Accuracy: 55.21%
#   Batch 8 | Loss: 0.8294 | Accuracy: 56.64%
#   Batch 10 | Loss: 0.7844 | Accuracy: 58.13%
#   Batch 12 | Loss: 1.0918 | Accuracy: 57.81%
#   Batch 14 | Loss: 0.8543 | Accuracy: 58.26%
#   Batch 16 | Loss: 0.9033 | Accuracy: 58.20%
#   Batch 18 | Loss: 0.6375 | Accuracy: 59.90%
#   Batch 20 | Loss: 0.8189 | Accuracy: 60.00%
#   Batch 22 | Loss: 0.9948 | Accuracy: 59.66%
#   Batch 24 | Loss: 0.9965 | Accuracy: 59.24%
#   Batch 26 | Loss: 0.8997 | Accuracy: 59.25%
#   Batch 28 | Loss: 0.9763 | Accuracy: 58.82%
#   Batch 30 | Loss: 0.8747 | Accuracy: 59.06%
#   Batch 32 | Loss: 0.9434 | Accuracy: 59.08%
#   Batch 34 | Loss: 0.7187 | Accuracy: 59.65%
#   Batch 36 | Loss: 0.9640 | Accuracy: 59.11%
#   Batch 38 | Loss: 0.8064 | Accuracy: 59.62%
#   Batch 40 | Loss: 0.8664 | Accuracy: 59.77%
#   Batch 42 | Loss: 1.0241 | Accuracy: 59.75%
#   Batch 44 | Loss: 0.8441 | Accuracy: 59.80%
#   Batch 46 | Loss: 0.6615 | Accuracy: 60.46%
#   Batch 48 | Loss: 0.7050 | Accuracy: 60.87%
#   Batch 50 | Loss: 0.8430 | Accuracy: 61.00%
#   Batch 52 | Loss: 0.7872 | Accuracy: 61.12%
#   Batch 54 | Loss: 0.8650 | Accuracy: 60.88%
#   Batch 56 | Loss: 0.8153 | Accuracy: 60.60%
#   Batch 58 | Loss: 0.8545 | Accuracy: 60.45%
#   Batch 60 | Loss: 0.7052 | Accuracy: 60.57%
#   Batch 62 | Loss: 0.6856 | Accuracy: 60.74%
#   Batch 64 | Loss: 0.7250 | Accuracy: 60.89%
#   Batch 66 | Loss: 0.8322 | Accuracy: 60.72%
# Epoch 2 Sonu | Train Loss: 0.8519 | Train Accuracy: 60.72%
# Validation (Epoch 2) | Accuracy: 58.17% | Loss: 0.8493
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.6739    0.4429    0.5345        70
#          MCI     0.5750    0.4792    0.5227        96
#           AD     0.5547    0.7835    0.6496        97
#
#     accuracy                         0.5817       263
#    macro avg     0.6012    0.5685    0.5689       263
# weighted avg     0.5939    0.5817    0.5726       263
#
# 🧩 Confusion Matrix:
# [[31 20 19]
#  [ 8 46 42]
#  [ 7 14 76]]
#
# Epoch 3/12
#   Batch 2 | Loss: 0.6895 | Accuracy: 73.44%
#   Batch 4 | Loss: 0.6583 | Accuracy: 74.22%
#   Batch 6 | Loss: 0.5891 | Accuracy: 72.92%
#   Batch 8 | Loss: 0.8891 | Accuracy: 71.09%
#   Batch 10 | Loss: 0.6037 | Accuracy: 70.00%
#   Batch 12 | Loss: 0.6182 | Accuracy: 70.57%
#   Batch 14 | Loss: 0.5878 | Accuracy: 69.42%
#   Batch 16 | Loss: 0.9327 | Accuracy: 67.97%
#   Batch 18 | Loss: 0.7472 | Accuracy: 68.23%
#   Batch 20 | Loss: 0.7056 | Accuracy: 68.75%
#   Batch 22 | Loss: 0.5818 | Accuracy: 69.60%
#   Batch 24 | Loss: 0.9197 | Accuracy: 68.75%
#   Batch 26 | Loss: 0.5279 | Accuracy: 68.75%
#   Batch 28 | Loss: 0.5363 | Accuracy: 69.08%
#   Batch 30 | Loss: 0.6297 | Accuracy: 69.27%
#   Batch 32 | Loss: 0.6190 | Accuracy: 69.63%
#   Batch 34 | Loss: 0.4961 | Accuracy: 69.76%
#   Batch 36 | Loss: 0.6522 | Accuracy: 69.44%
#   Batch 38 | Loss: 0.5410 | Accuracy: 69.57%
#   Batch 40 | Loss: 0.5691 | Accuracy: 69.77%
#   Batch 42 | Loss: 0.6855 | Accuracy: 69.94%
#   Batch 44 | Loss: 0.5803 | Accuracy: 69.96%
#   Batch 46 | Loss: 0.6401 | Accuracy: 70.11%
#   Batch 48 | Loss: 0.5789 | Accuracy: 70.31%
#   Batch 50 | Loss: 0.5298 | Accuracy: 70.56%
#   Batch 52 | Loss: 0.9999 | Accuracy: 70.31%
#   Batch 54 | Loss: 0.8802 | Accuracy: 69.91%
#   Batch 56 | Loss: 0.6988 | Accuracy: 69.98%
#   Batch 58 | Loss: 0.6068 | Accuracy: 70.04%
#   Batch 60 | Loss: 0.6318 | Accuracy: 70.21%
#   Batch 62 | Loss: 0.7609 | Accuracy: 70.11%
#   Batch 64 | Loss: 0.8339 | Accuracy: 69.73%
#   Batch 66 | Loss: 0.9909 | Accuracy: 69.50%
# Epoch 3 Sonu | Train Loss: 0.6993 | Train Accuracy: 69.50%
# Validation (Epoch 3) | Accuracy: 33.46% | Loss: 1.9463
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.2949    0.9143    0.4460        70
#          MCI     0.4762    0.2083    0.2899        96
#           AD     1.0000    0.0412    0.0792        97
#
#     accuracy                         0.3346       263
#    macro avg     0.5904    0.3880    0.2717       263
# weighted avg     0.6211    0.3346    0.2537       263
#
# 🧩 Confusion Matrix:
# [[64  6  0]
#  [76 20  0]
#  [77 16  4]]
#   ⚠️ Validation loss iyileşmedi. (1/3)
#
# Epoch 4/12
#   Batch 2 | Loss: 0.5981 | Accuracy: 81.25%
#   Batch 4 | Loss: 0.7340 | Accuracy: 74.22%
#   Batch 6 | Loss: 0.6307 | Accuracy: 73.96%
#   Batch 8 | Loss: 0.7871 | Accuracy: 73.44%
#   Batch 10 | Loss: 0.6251 | Accuracy: 73.75%
#   Batch 12 | Loss: 0.5542 | Accuracy: 73.70%
#   Batch 14 | Loss: 0.4723 | Accuracy: 74.33%
#   Batch 16 | Loss: 0.4324 | Accuracy: 74.80%
#   Batch 18 | Loss: 0.4925 | Accuracy: 75.35%
#   Batch 20 | Loss: 0.3378 | Accuracy: 76.56%
#   Batch 22 | Loss: 0.4675 | Accuracy: 76.42%
#   Batch 24 | Loss: 0.5597 | Accuracy: 77.08%
#   Batch 26 | Loss: 0.3123 | Accuracy: 77.76%
#   Batch 28 | Loss: 0.4977 | Accuracy: 77.68%
#   Batch 30 | Loss: 0.3975 | Accuracy: 77.19%
#   Batch 32 | Loss: 0.3790 | Accuracy: 77.44%
#   Batch 34 | Loss: 0.5304 | Accuracy: 77.57%
#   Batch 36 | Loss: 0.5713 | Accuracy: 77.52%
#   Batch 38 | Loss: 0.4809 | Accuracy: 77.71%
#   Batch 40 | Loss: 0.2703 | Accuracy: 77.89%
#   Batch 42 | Loss: 0.5389 | Accuracy: 78.05%
#   Batch 44 | Loss: 0.8991 | Accuracy: 77.98%
#   Batch 46 | Loss: 0.5075 | Accuracy: 78.26%
#   Batch 48 | Loss: 0.4003 | Accuracy: 78.45%
#   Batch 50 | Loss: 0.5817 | Accuracy: 78.44%
#   Batch 52 | Loss: 0.4223 | Accuracy: 78.43%
#   Batch 54 | Loss: 0.7232 | Accuracy: 78.12%
#   Batch 56 | Loss: 0.9675 | Accuracy: 77.57%
#   Batch 58 | Loss: 0.4899 | Accuracy: 77.59%
#   Batch 60 | Loss: 0.4276 | Accuracy: 77.66%
#   Batch 62 | Loss: 0.6547 | Accuracy: 77.47%
#   Batch 64 | Loss: 0.7331 | Accuracy: 77.44%
#   Batch 66 | Loss: 0.5428 | Accuracy: 77.61%
# Epoch 4 Sonu | Train Loss: 0.5603 | Train Accuracy: 77.61%
# Validation (Epoch 4) | Accuracy: 64.64% | Loss: 0.8888
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.6026    0.6714    0.6351        70
#          MCI     0.8333    0.3125    0.4545        96
#           AD     0.6242    0.9588    0.7561        97
#
#     accuracy                         0.6464       263
#    macro avg     0.6867    0.6476    0.6153       263
# weighted avg     0.6948    0.6464    0.6138       263
#
# 🧩 Confusion Matrix:
# [[47  4 19]
#  [29 30 37]
#  [ 2  2 93]]
#   ⚠️ Validation loss iyileşmedi. (2/3)
#
# Epoch 5/12
#   Batch 2 | Loss: 0.4655 | Accuracy: 82.81%
#   Batch 4 | Loss: 0.5402 | Accuracy: 83.59%
#   Batch 6 | Loss: 0.2036 | Accuracy: 84.38%
#   Batch 8 | Loss: 0.4575 | Accuracy: 83.20%
#   Batch 10 | Loss: 0.3993 | Accuracy: 84.38%
#   Batch 12 | Loss: 0.3017 | Accuracy: 84.90%
#   Batch 14 | Loss: 0.3655 | Accuracy: 84.82%
#   Batch 16 | Loss: 0.2824 | Accuracy: 84.96%
#   Batch 18 | Loss: 0.3856 | Accuracy: 85.07%
#   Batch 20 | Loss: 0.4577 | Accuracy: 85.00%
#   Batch 22 | Loss: 0.2726 | Accuracy: 85.51%
#   Batch 24 | Loss: 0.5109 | Accuracy: 85.03%
#   Batch 26 | Loss: 0.3963 | Accuracy: 84.86%
#   Batch 28 | Loss: 0.4425 | Accuracy: 85.27%
#   Batch 30 | Loss: 0.4275 | Accuracy: 85.21%
#   Batch 32 | Loss: 0.2441 | Accuracy: 85.06%
#   Batch 34 | Loss: 0.5113 | Accuracy: 85.02%
#   Batch 36 | Loss: 0.3115 | Accuracy: 85.24%
#   Batch 38 | Loss: 0.3475 | Accuracy: 85.53%
#   Batch 40 | Loss: 0.5036 | Accuracy: 85.23%
#   Batch 42 | Loss: 0.2379 | Accuracy: 85.57%
#   Batch 44 | Loss: 0.4351 | Accuracy: 85.23%
#   Batch 46 | Loss: 0.2155 | Accuracy: 85.53%
#   Batch 48 | Loss: 0.3135 | Accuracy: 85.87%
#   Batch 50 | Loss: 0.2728 | Accuracy: 86.00%
#   Batch 52 | Loss: 0.4236 | Accuracy: 86.24%
#   Batch 54 | Loss: 0.6367 | Accuracy: 86.17%
#   Batch 56 | Loss: 0.3653 | Accuracy: 86.38%
#   Batch 58 | Loss: 0.4656 | Accuracy: 86.15%
#   Batch 60 | Loss: 0.2402 | Accuracy: 86.20%
#   Batch 62 | Loss: 0.6063 | Accuracy: 85.94%
#   Batch 64 | Loss: 0.2852 | Accuracy: 85.74%
#   Batch 66 | Loss: 0.2393 | Accuracy: 85.77%
# Epoch 5 Sonu | Train Loss: 0.3702 | Train Accuracy: 85.77%
# Validation (Epoch 5) | Accuracy: 63.88% | Loss: 0.8038
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.4733    0.8857    0.6169        70
#          MCI     0.7179    0.5833    0.6437        96
#           AD     0.9259    0.5155    0.6623        97
#
#     accuracy                         0.6388       263
#    macro avg     0.7057    0.6615    0.6409       263
# weighted avg     0.7295    0.6388    0.6434       263
#
# 🧩 Confusion Matrix:
# [[62  7  1]
#  [37 56  3]
#  [32 15 50]]
#
# Epoch 6/12
#   Batch 2 | Loss: 0.3729 | Accuracy: 93.75%
#   Batch 4 | Loss: 0.1837 | Accuracy: 93.75%
#   Batch 6 | Loss: 0.2075 | Accuracy: 92.71%
#   Batch 8 | Loss: 0.2427 | Accuracy: 91.41%
#   Batch 10 | Loss: 0.3441 | Accuracy: 90.62%
#   Batch 12 | Loss: 0.2421 | Accuracy: 91.15%
#   Batch 14 | Loss: 0.1840 | Accuracy: 90.85%
#   Batch 16 | Loss: 0.3845 | Accuracy: 90.82%
#   Batch 18 | Loss: 0.1115 | Accuracy: 91.49%
#   Batch 20 | Loss: 0.1547 | Accuracy: 92.19%
#   Batch 22 | Loss: 0.1394 | Accuracy: 92.33%
#   Batch 24 | Loss: 0.3265 | Accuracy: 92.45%
#   Batch 26 | Loss: 0.1939 | Accuracy: 92.55%
#   Batch 28 | Loss: 0.2694 | Accuracy: 92.19%
#   Batch 30 | Loss: 0.2089 | Accuracy: 92.29%
#   Batch 32 | Loss: 0.4410 | Accuracy: 91.99%
#   Batch 34 | Loss: 0.5547 | Accuracy: 91.45%
#   Batch 36 | Loss: 0.2915 | Accuracy: 91.75%
#   Batch 38 | Loss: 0.1728 | Accuracy: 92.11%
#   Batch 40 | Loss: 0.2469 | Accuracy: 92.19%
#   Batch 42 | Loss: 0.4516 | Accuracy: 91.89%
#   Batch 44 | Loss: 0.1009 | Accuracy: 91.76%
#   Batch 46 | Loss: 0.2595 | Accuracy: 91.78%
#   Batch 48 | Loss: 0.3538 | Accuracy: 91.60%
#   Batch 50 | Loss: 0.4915 | Accuracy: 91.31%
#   Batch 52 | Loss: 0.1877 | Accuracy: 91.35%
#   Batch 54 | Loss: 0.4172 | Accuracy: 91.32%
#   Batch 56 | Loss: 0.2458 | Accuracy: 91.35%
#   Batch 58 | Loss: 0.3182 | Accuracy: 91.27%
#   Batch 60 | Loss: 0.2075 | Accuracy: 91.30%
#   Batch 62 | Loss: 0.4320 | Accuracy: 90.98%
#   Batch 64 | Loss: 0.4338 | Accuracy: 90.77%
#   Batch 66 | Loss: 0.3612 | Accuracy: 90.61%
# Epoch 6 Sonu | Train Loss: 0.2751 | Train Accuracy: 90.61%
# Validation (Epoch 6) | Accuracy: 60.46% | Loss: 1.1756
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.4314    0.9429    0.5919        70
#          MCI     0.8824    0.3125    0.4615        96
#           AD     0.8289    0.6495    0.7283        97
#
#     accuracy                         0.6046       263
#    macro avg     0.7142    0.6349    0.5939       263
# weighted avg     0.7426    0.6046    0.5946       263
#
# 🧩 Confusion Matrix:
# [[66  3  1]
#  [54 30 12]
#  [33  1 63]]
#   ⚠️ Validation loss iyileşmedi. (1/3)
#
# Epoch 7/12
#   Batch 2 | Loss: 0.3054 | Accuracy: 89.06%
#   Batch 4 | Loss: 0.2592 | Accuracy: 90.62%
#   Batch 6 | Loss: 0.2033 | Accuracy: 90.10%
#   Batch 8 | Loss: 0.2009 | Accuracy: 90.62%
#   Batch 10 | Loss: 0.1742 | Accuracy: 89.38%
#   Batch 12 | Loss: 0.3264 | Accuracy: 89.84%
#   Batch 14 | Loss: 0.2619 | Accuracy: 90.40%
#   Batch 16 | Loss: 0.1271 | Accuracy: 90.82%
#   Batch 18 | Loss: 0.2846 | Accuracy: 90.62%
#   Batch 20 | Loss: 0.0935 | Accuracy: 91.25%
#   Batch 22 | Loss: 0.2579 | Accuracy: 91.48%
#   Batch 24 | Loss: 0.1089 | Accuracy: 91.80%
#   Batch 26 | Loss: 0.1532 | Accuracy: 91.71%
#   Batch 28 | Loss: 0.2712 | Accuracy: 91.63%
#   Batch 30 | Loss: 0.0857 | Accuracy: 92.19%
#   Batch 32 | Loss: 0.1791 | Accuracy: 92.29%
#   Batch 34 | Loss: 0.2684 | Accuracy: 92.00%
#   Batch 36 | Loss: 0.1156 | Accuracy: 92.36%
#   Batch 38 | Loss: 0.1015 | Accuracy: 92.52%
#   Batch 40 | Loss: 0.3404 | Accuracy: 92.19%
#   Batch 42 | Loss: 0.1448 | Accuracy: 92.19%
#   Batch 44 | Loss: 0.4322 | Accuracy: 91.76%
#   Batch 46 | Loss: 0.1644 | Accuracy: 91.71%
#   Batch 48 | Loss: 0.1865 | Accuracy: 91.86%
#   Batch 50 | Loss: 0.2843 | Accuracy: 91.94%
#   Batch 52 | Loss: 0.3057 | Accuracy: 91.77%
#   Batch 54 | Loss: 0.0754 | Accuracy: 91.96%
#   Batch 56 | Loss: 0.1710 | Accuracy: 92.19%
#   Batch 58 | Loss: 0.1989 | Accuracy: 92.13%
#   Batch 60 | Loss: 0.2064 | Accuracy: 92.34%
#   Batch 62 | Loss: 0.1406 | Accuracy: 92.44%
#   Batch 64 | Loss: 0.1831 | Accuracy: 92.58%
#   Batch 66 | Loss: 0.0601 | Accuracy: 92.55%
# Epoch 7 Sonu | Train Loss: 0.2111 | Train Accuracy: 92.55%
# Validation (Epoch 7) | Accuracy: 79.09% | Loss: 0.6296
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.7500    0.7286    0.7391        70
#          MCI     0.7921    0.8333    0.8122        96
#           AD     0.8191    0.7938    0.8063        97
#
#     accuracy                         0.7909       263
#    macro avg     0.7871    0.7852    0.7859       263
# weighted avg     0.7909    0.7909    0.7906       263
#
# 🧩 Confusion Matrix:
# [[51 11  8]
#  [ 7 80  9]
#  [10 10 77]]
#
# Epoch 8/12
#   Batch 2 | Loss: 0.2155 | Accuracy: 92.19%
#   Batch 4 | Loss: 0.3417 | Accuracy: 90.62%
#   Batch 6 | Loss: 0.0768 | Accuracy: 92.71%
#   Batch 8 | Loss: 0.1534 | Accuracy: 93.36%
#   Batch 10 | Loss: 0.3407 | Accuracy: 91.88%
#   Batch 12 | Loss: 0.1048 | Accuracy: 93.23%
#   Batch 14 | Loss: 0.0707 | Accuracy: 93.53%
#   Batch 16 | Loss: 0.2608 | Accuracy: 93.55%
#   Batch 18 | Loss: 0.1254 | Accuracy: 93.75%
#   Batch 20 | Loss: 0.1349 | Accuracy: 93.59%
#   Batch 22 | Loss: 0.1534 | Accuracy: 93.47%
#   Batch 24 | Loss: 0.3306 | Accuracy: 93.49%
#   Batch 26 | Loss: 0.1315 | Accuracy: 93.63%
#   Batch 28 | Loss: 0.0864 | Accuracy: 94.08%
#   Batch 30 | Loss: 0.3631 | Accuracy: 93.65%
#   Batch 32 | Loss: 0.1527 | Accuracy: 93.46%
#   Batch 34 | Loss: 0.0865 | Accuracy: 93.47%
#   Batch 36 | Loss: 0.2426 | Accuracy: 93.49%
#   Batch 38 | Loss: 0.1059 | Accuracy: 93.50%
#   Batch 40 | Loss: 0.0520 | Accuracy: 93.75%
#   Batch 42 | Loss: 0.1830 | Accuracy: 93.68%
#   Batch 44 | Loss: 0.1365 | Accuracy: 93.68%
#   Batch 46 | Loss: 0.1925 | Accuracy: 93.55%
#   Batch 48 | Loss: 0.0701 | Accuracy: 93.75%
#   Batch 50 | Loss: 0.3166 | Accuracy: 93.69%
#   Batch 52 | Loss: 0.1841 | Accuracy: 93.63%
#   Batch 54 | Loss: 0.1938 | Accuracy: 93.63%
#   Batch 56 | Loss: 0.5751 | Accuracy: 93.53%
#   Batch 58 | Loss: 0.1690 | Accuracy: 93.48%
#   Batch 60 | Loss: 0.1994 | Accuracy: 93.49%
#   Batch 62 | Loss: 0.0933 | Accuracy: 93.65%
#   Batch 64 | Loss: 0.2300 | Accuracy: 93.70%
#   Batch 66 | Loss: 0.1992 | Accuracy: 93.45%
# Epoch 8 Sonu | Train Loss: 0.1900 | Train Accuracy: 93.45%
# Validation (Epoch 8) | Accuracy: 75.67% | Loss: 0.6741
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.7869    0.6857    0.7328        70
#          MCI     0.8788    0.6042    0.7160        96
#           AD     0.6838    0.9588    0.7983        97
#
#     accuracy                         0.7567       263
#    macro avg     0.7832    0.7495    0.7491       263
# weighted avg     0.7824    0.7567    0.7508       263
#
# 🧩 Confusion Matrix:
# [[48  8 14]
#  [ 9 58 29]
#  [ 4  0 93]]
#   ⚠️ Validation loss iyileşmedi. (1/3)
#
# Epoch 9/12
#   Batch 2 | Loss: 0.3228 | Accuracy: 92.19%
#   Batch 4 | Loss: 0.2538 | Accuracy: 94.53%
#   Batch 6 | Loss: 0.0511 | Accuracy: 95.31%
#   Batch 8 | Loss: 0.1532 | Accuracy: 94.92%
#   Batch 10 | Loss: 0.2949 | Accuracy: 94.69%
#   Batch 12 | Loss: 0.1314 | Accuracy: 94.79%
#   Batch 14 | Loss: 0.2273 | Accuracy: 94.87%
#   Batch 16 | Loss: 0.2790 | Accuracy: 94.92%
#   Batch 18 | Loss: 0.2546 | Accuracy: 93.58%
#   Batch 20 | Loss: 0.2215 | Accuracy: 93.75%
#   Batch 22 | Loss: 0.2207 | Accuracy: 93.61%
#   Batch 24 | Loss: 0.2189 | Accuracy: 93.36%
#   Batch 26 | Loss: 0.2881 | Accuracy: 92.91%
#   Batch 28 | Loss: 0.1011 | Accuracy: 93.19%
#   Batch 30 | Loss: 0.0290 | Accuracy: 93.02%
#   Batch 32 | Loss: 0.1677 | Accuracy: 93.16%
#   Batch 34 | Loss: 0.0413 | Accuracy: 93.57%
#   Batch 36 | Loss: 0.0779 | Accuracy: 93.66%
#   Batch 38 | Loss: 0.1130 | Accuracy: 93.59%
#   Batch 40 | Loss: 0.0872 | Accuracy: 93.91%
#   Batch 42 | Loss: 0.2373 | Accuracy: 93.53%
#   Batch 44 | Loss: 0.0963 | Accuracy: 93.75%
#   Batch 46 | Loss: 0.1963 | Accuracy: 93.89%
#   Batch 48 | Loss: 0.2555 | Accuracy: 93.88%
#   Batch 50 | Loss: 0.1429 | Accuracy: 93.69%
#   Batch 52 | Loss: 0.0782 | Accuracy: 93.81%
#   Batch 54 | Loss: 0.1596 | Accuracy: 93.81%
#   Batch 56 | Loss: 0.0468 | Accuracy: 93.97%
#   Batch 58 | Loss: 0.1872 | Accuracy: 94.02%
#   Batch 60 | Loss: 0.0466 | Accuracy: 94.17%
#   Batch 62 | Loss: 0.0781 | Accuracy: 94.20%
#   Batch 64 | Loss: 0.2246 | Accuracy: 94.19%
#   Batch 66 | Loss: 0.1385 | Accuracy: 94.26%
# Epoch 9 Sonu | Train Loss: 0.1556 | Train Accuracy: 94.26%
# Validation (Epoch 9) | Accuracy: 80.99% | Loss: 0.4755
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.7922    0.8714    0.8299        70
#          MCI     0.7179    0.8750    0.7887        96
#           AD     0.9855    0.7010    0.8193        97
#
#     accuracy                         0.8099       263
#    macro avg     0.8319    0.8158    0.8126       263
# weighted avg     0.8364    0.8099    0.8110       263
#
# 🧩 Confusion Matrix:
# [[61  9  0]
#  [11 84  1]
#  [ 5 24 68]]
#
# Epoch 10/12
#   Batch 2 | Loss: 0.0458 | Accuracy: 100.00%
#   Batch 4 | Loss: 0.0178 | Accuracy: 98.44%
#   Batch 6 | Loss: 0.0653 | Accuracy: 98.44%
#   Batch 8 | Loss: 0.0697 | Accuracy: 98.83%
#   Batch 10 | Loss: 0.0424 | Accuracy: 99.06%
#   Batch 12 | Loss: 0.0481 | Accuracy: 98.70%
#   Batch 14 | Loss: 0.0729 | Accuracy: 98.66%
#   Batch 16 | Loss: 0.0298 | Accuracy: 98.83%
#   Batch 18 | Loss: 0.0557 | Accuracy: 98.61%
#   Batch 20 | Loss: 0.0206 | Accuracy: 98.59%
#   Batch 22 | Loss: 0.0554 | Accuracy: 98.44%
#   Batch 24 | Loss: 0.1661 | Accuracy: 98.18%
#   Batch 26 | Loss: 0.0150 | Accuracy: 98.20%
#   Batch 28 | Loss: 0.0258 | Accuracy: 98.33%
#   Batch 30 | Loss: 0.0260 | Accuracy: 98.23%
#   Batch 32 | Loss: 0.0220 | Accuracy: 98.24%
#   Batch 34 | Loss: 0.1027 | Accuracy: 98.07%
#   Batch 36 | Loss: 0.1997 | Accuracy: 97.83%
#   Batch 38 | Loss: 0.2217 | Accuracy: 97.53%
#   Batch 40 | Loss: 0.0208 | Accuracy: 97.50%
#   Batch 42 | Loss: 0.2299 | Accuracy: 97.40%
#   Batch 44 | Loss: 0.0452 | Accuracy: 97.23%
#   Batch 46 | Loss: 0.0610 | Accuracy: 96.88%
#   Batch 48 | Loss: 0.2023 | Accuracy: 96.88%
#   Batch 50 | Loss: 0.1898 | Accuracy: 96.62%
#   Batch 52 | Loss: 0.2197 | Accuracy: 96.51%
#   Batch 54 | Loss: 0.0711 | Accuracy: 96.47%
#   Batch 56 | Loss: 0.0923 | Accuracy: 96.48%
#   Batch 58 | Loss: 0.1652 | Accuracy: 96.39%
#   Batch 60 | Loss: 0.0743 | Accuracy: 96.35%
#   Batch 62 | Loss: 0.1364 | Accuracy: 96.22%
#   Batch 64 | Loss: 0.3009 | Accuracy: 96.19%
#   Batch 66 | Loss: 0.1457 | Accuracy: 96.06%
# Epoch 10 Sonu | Train Loss: 0.1078 | Train Accuracy: 96.06%
# Validation (Epoch 10) | Accuracy: 50.57% | Loss: 2.2318
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.9444    0.2429    0.3864        70
#          MCI     0.9048    0.1979    0.3248        96
#           AD     0.4330    1.0000    0.6044        97
#
#     accuracy                         0.5057       263
#    macro avg     0.7607    0.4803    0.4385       263
# weighted avg     0.7413    0.5057    0.4443       263
#
# 🧩 Confusion Matrix:
# [[17  2 51]
#  [ 1 19 76]
#  [ 0  0 97]]
#   ⚠️ Validation loss iyileşmedi. (1/3)
#
# Epoch 11/12
#   Batch 2 | Loss: 0.0804 | Accuracy: 96.88%
#   Batch 4 | Loss: 0.1990 | Accuracy: 96.09%
#   Batch 6 | Loss: 0.0728 | Accuracy: 96.88%
#   Batch 8 | Loss: 0.0760 | Accuracy: 96.48%
#   Batch 10 | Loss: 0.0496 | Accuracy: 96.88%
#   Batch 12 | Loss: 0.0306 | Accuracy: 97.40%
#   Batch 14 | Loss: 0.0753 | Accuracy: 97.32%
#   Batch 16 | Loss: 0.0662 | Accuracy: 97.27%
#   Batch 18 | Loss: 0.2546 | Accuracy: 96.88%
#   Batch 20 | Loss: 0.0810 | Accuracy: 96.72%
#   Batch 22 | Loss: 0.0344 | Accuracy: 97.02%
#   Batch 24 | Loss: 0.0484 | Accuracy: 96.88%
#   Batch 26 | Loss: 0.0764 | Accuracy: 96.88%
#   Batch 28 | Loss: 0.0461 | Accuracy: 96.99%
#   Batch 30 | Loss: 0.0272 | Accuracy: 96.88%
#   Batch 32 | Loss: 0.1036 | Accuracy: 96.97%
#   Batch 34 | Loss: 0.0374 | Accuracy: 97.15%
#   Batch 36 | Loss: 0.0205 | Accuracy: 97.22%
#   Batch 38 | Loss: 0.2587 | Accuracy: 97.04%
#   Batch 40 | Loss: 0.0912 | Accuracy: 96.95%
#   Batch 42 | Loss: 0.0482 | Accuracy: 96.73%
#   Batch 44 | Loss: 0.0453 | Accuracy: 96.80%
#   Batch 46 | Loss: 0.1257 | Accuracy: 96.88%
#   Batch 48 | Loss: 0.2169 | Accuracy: 96.81%
#   Batch 50 | Loss: 0.0161 | Accuracy: 96.94%
#   Batch 52 | Loss: 0.1650 | Accuracy: 97.00%
#   Batch 54 | Loss: 0.0386 | Accuracy: 97.11%
#   Batch 56 | Loss: 0.0440 | Accuracy: 97.21%
#   Batch 58 | Loss: 0.0270 | Accuracy: 97.31%
#   Batch 60 | Loss: 0.1956 | Accuracy: 97.24%
#   Batch 62 | Loss: 0.0236 | Accuracy: 97.23%
#   Batch 64 | Loss: 0.0515 | Accuracy: 97.31%
#   Batch 66 | Loss: 0.0816 | Accuracy: 97.30%
# Epoch 11 Sonu | Train Loss: 0.0942 | Train Accuracy: 97.30%
# Validation (Epoch 11) | Accuracy: 66.92% | Loss: 1.0341
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.4718    0.9571    0.6321        70
#          MCI     0.9444    0.3542    0.5152        96
#           AD     0.8824    0.7732    0.8242        97
#
#     accuracy                         0.6692       263
#    macro avg     0.7662    0.6948    0.6571       263
# weighted avg     0.7958    0.6692    0.6602       263
#
# 🧩 Confusion Matrix:
# [[67  2  1]
#  [53 34  9]
#  [22  0 75]]
#   ⚠️ Validation loss iyileşmedi. (2/3)
#
# Epoch 12/12
#   Batch 2 | Loss: 0.0293 | Accuracy: 96.88%
#   Batch 4 | Loss: 0.2635 | Accuracy: 96.88%
#   Batch 6 | Loss: 0.0153 | Accuracy: 96.35%
#   Batch 8 | Loss: 0.1181 | Accuracy: 96.48%
#   Batch 10 | Loss: 0.0165 | Accuracy: 97.19%
#   Batch 12 | Loss: 0.0495 | Accuracy: 97.14%
#   Batch 14 | Loss: 0.0473 | Accuracy: 97.32%
#   Batch 16 | Loss: 0.1090 | Accuracy: 96.48%
#   Batch 18 | Loss: 0.2517 | Accuracy: 95.83%
#   Batch 20 | Loss: 0.0278 | Accuracy: 95.78%
#   Batch 22 | Loss: 0.0277 | Accuracy: 96.16%
#   Batch 24 | Loss: 0.1196 | Accuracy: 95.70%
#   Batch 26 | Loss: 0.1161 | Accuracy: 95.91%
#   Batch 28 | Loss: 0.0563 | Accuracy: 96.21%
#   Batch 30 | Loss: 0.1666 | Accuracy: 96.35%
#   Batch 32 | Loss: 0.0372 | Accuracy: 96.48%
#   Batch 34 | Loss: 0.1342 | Accuracy: 96.42%
#   Batch 36 | Loss: 0.0404 | Accuracy: 96.53%
#   Batch 38 | Loss: 0.0247 | Accuracy: 96.63%
#   Batch 40 | Loss: 0.0281 | Accuracy: 96.72%
#   Batch 42 | Loss: 0.0333 | Accuracy: 96.88%
#   Batch 44 | Loss: 0.0944 | Accuracy: 96.95%
#   Batch 46 | Loss: 0.0125 | Accuracy: 96.94%
#   Batch 48 | Loss: 0.0429 | Accuracy: 97.07%
#   Batch 50 | Loss: 0.1787 | Accuracy: 97.00%
#   Batch 52 | Loss: 0.0226 | Accuracy: 97.12%
#   Batch 54 | Loss: 0.1015 | Accuracy: 97.16%
#   Batch 56 | Loss: 0.0262 | Accuracy: 97.10%
#   Batch 58 | Loss: 0.0244 | Accuracy: 97.20%
#   Batch 60 | Loss: 0.0998 | Accuracy: 97.24%
#   Batch 62 | Loss: 0.0288 | Accuracy: 97.33%
#   Batch 64 | Loss: 0.0143 | Accuracy: 97.31%
#   Batch 66 | Loss: 0.0438 | Accuracy: 97.39%
# Epoch 12 Sonu | Train Loss: 0.0817 | Train Accuracy: 97.39%
# Validation (Epoch 12) | Accuracy: 71.10% | Loss: 0.8490
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.5000    1.0000    0.6667        70
#          MCI     0.9787    0.4792    0.6434        96
#           AD     0.9342    0.7320    0.8208        97
#
#     accuracy                         0.7110       263
#    macro avg     0.8043    0.7370    0.7103       263
# weighted avg     0.8349    0.7110    0.7150       263
#
# 🧩 Confusion Matrix:
# [[70  0  0]
#  [45 46  5]
#  [25  1 71]]
#   ⚠️ Validation loss iyileşmedi. (3/3)
#   🛑 Validation loss 3 epoch boyunca iyileşmedi. Eğitim durduruluyor.
#
# === Final Test Evaluation ===
# Test Set | Accuracy: 77.65% | Loss: 0.7151
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#           CN     0.6269    0.9231    0.7467        91
#          MCI     0.9123    0.6047    0.7273        86
#           AD     0.9452    0.7931    0.8625        87
#
#     accuracy                         0.7765       264
#    macro avg     0.8281    0.7736    0.7788       264
# weighted avg     0.8247    0.7765    0.7785       264
#
# 🧩 Confusion Matrix:
# [[84  4  3]
#  [33 52  1]
#  [17  1 69]]

# %%
# Modeli kaydet (state_dict)
torch.save(model.state_dict(), 'best_densenet3d_model_orig.pth')
print("✅ Model başarıyla 'best_densenet3d_model.pth' dosyasına kaydedildi.")
# Out:
# ✅ Model başarıyla 'best_densenet3d_model.pth' dosyasına kaydedildi.
